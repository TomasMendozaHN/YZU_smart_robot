# %% [markdown]
# # How to modify MLAgents to export the model to Pytorch rather than Onnx

# %% [markdown]
# ### Start by going to the path where you have your Anaconda installed.

# %% [markdown]
# ### Once there, go to your "envs" folder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Here is the list of your installed environments. Go to the folder of the environment where you have mlagents installed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Then go to "Lib" folder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Then go to "site-packages". This is where all the libraries you installed using pip are located

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Here you should find mlagents. If you don't, you're in the wrong environment!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Now go to the following path (/mlagents/trainers/torch)and open the model_serialization.py file in a text editor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Add the highlighted line in the method "def export_policy_model..."

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Don't forget to save! Now, in the same path where mlagents saves the onnx file it will also save your pytorch model!
